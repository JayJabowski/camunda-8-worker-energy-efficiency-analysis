# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

#read kepler CSV
worker_power = pd.read_csv("CSV-Misc/load_test_CPU.csv", 
                     header=1, # which row contains column headers
                     index_col=0   ) # which column contains labels

worker_power.iloc[: 12*2,:].plot(figsize=[12,6], legend=False, ylabel='CPU Nutzung (%)', title= 'CPU-Nutzung Testszenario 3 (Ausschnitt)')
# Out:
# <Axes: title={'center': 'CPU-Nutzung Testszenario 3 (Ausschnitt)'}, xlabel='Time', ylabel='CPU Nutzung (%)'>
